# %% [markdown]
# # 9.5 ChIP データの品質管理（QC）

# %%
# ChIP-seq のデータを読み込む
chip_files = list.files("../data/chip-seq", full.names=TRUE)

# %%
# 染色体情報を読み込むライブラリを呼び出す
library(GenomeInfoDb)

# %%
# ヒトゲノムの染色体長を取得
hg_chrs = getChromInfoFromUCSC('hg38')

# %%
## ヒトゲノムの染色体長が表示される
hg_chrs
# Out:
#     chrom                size      assembled circular
# 1   chr1                 248956422  TRUE     FALSE
# 2   chr2                 242193529  TRUE     FALSE
# 3   chr3                 198295559  TRUE     FALSE
# 4   chr4                 190214555  TRUE     FALSE
# 5   chr5                 181538259  TRUE     FALSE
# 6   chr6                 170805979  TRUE     FALSE
# 7   chr7                 159345973  TRUE     FALSE
# 8   chr8                 145138636  TRUE     FALSE
# 9   chr9                 138394717  TRUE     FALSE
# 10  chr10                133797422  TRUE     FALSE
# 11  chr11                135086622  TRUE     FALSE
# 12  chr12                133275309  TRUE     FALSE
# 13  chr13                114364328  TRUE     FALSE
# 14  chr14                107043718  TRUE     FALSE
# 15  chr15                101991189  TRUE     FALSE
# 16  chr16                 90338345  TRUE     FALSE
# 17  chr17                 83257441  TRUE     FALSE
# 18  chr18                 80373285  TRUE     FALSE
# 19  chr19                 58617616  TRUE     FALSE
# 20  chr20                 64444167  TRUE     FALSE
# 21  chr21                 46709983  TRUE     FALSE
# 22  chr22                 50818468  TRUE     FALSE
# 23  chrX                 156040895  TRUE     FALSE
# 24  chrY                  57227415  TRUE     FALSE
# 25  chrM                     16569  TRUE      TRUE
# 26  chr1_GL383518v1_alt     182439 FALSE     FALSE
# 27  chr1_GL383519v1_alt     110268 FALSE     FALSE
# 28  chr1_GL383520v2_alt     366580 FALSE     FALSE
# 29  chr1_KI270759v1_alt     425601 FALSE     FALSE
# 30  chr1_KI270760v1_alt     109528 FALSE     FALSE
# ⋮   ⋮                    ⋮         ⋮         ⋮
# 566 chr16_KQ031390v1_alt 169136    FALSE     FALSE
# 567 chr16_KQ090026v1_alt  59016    FALSE     FALSE
# 568 chr16_KQ090027v1_alt 267463    FALSE     FALSE
# 569 chr16_KZ208921v1_alt  78609    FALSE     FALSE
# 570 chr17_KV766197v1_alt 246895    FALSE     FALSE
# 571 chr17_KV766198v1_alt 276292    FALSE     FALSE
# 572 chr17_KZ559114v1_alt 116753    FALSE     FALSE
# 573 chr18_KQ458385v1_alt 205101    FALSE     FALSE
# 574 chr18_KZ559116v1_alt 163186    FALSE     FALSE
# 575 chr19_KV575246v1_alt 163926    FALSE     FALSE
# 576 chr19_KV575247v1_alt 170206    FALSE     FALSE
# 577 chr19_KV575248v1_alt 168131    FALSE     FALSE
# 578 chr19_KV575249v1_alt 293522    FALSE     FALSE
# 579 chr19_KV575250v1_alt 241058    FALSE     FALSE
# 580 chr19_KV575251v1_alt 159285    FALSE     FALSE
# 581 chr19_KV575252v1_alt 178197    FALSE     FALSE
# 582 chr19_KV575253v1_alt 166713    FALSE     FALSE
# 583 chr19_KV575254v1_alt  99845    FALSE     FALSE
# 584 chr19_KV575255v1_alt 161095    FALSE     FALSE
# 585 chr19_KV575256v1_alt 223118    FALSE     FALSE
# 586 chr19_KV575257v1_alt 100553    FALSE     FALSE
# 587 chr19_KV575258v1_alt 156965    FALSE     FALSE
# 588 chr19_KV575259v1_alt 171263    FALSE     FALSE
# 589 chr19_KV575260v1_alt 145691    FALSE     FALSE
# 590 chr22_KN196485v1_alt 156562    FALSE     FALSE
# 591 chr22_KN196486v1_alt 153027    FALSE     FALSE
# 592 chr22_KQ458387v1_alt 155930    FALSE     FALSE
# 593 chr22_KQ458388v1_alt 174749    FALSE     FALSE
# 594 chr22_KQ759761v1_alt 145162    FALSE     FALSE
# 595 chrX_KV766199v1_alt  188004    FALSE     FALSE
